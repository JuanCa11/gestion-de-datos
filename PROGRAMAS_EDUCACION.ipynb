# %%
import pandas as pd
import numpy as np
df = pd.read_csv('PROGRAMAS_DE_EDUCACI_N_SUPERIOR.csv')
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(5)
# Out:
#    codigoinstitucion                                 nombreinstitucion  \
# 0               2747  FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS
# 1               1101                  UNIVERSIDAD NACIONAL DE COLOMBIA
# 2               1101                  UNIVERSIDAD NACIONAL DE COLOMBIA
# 3               1101                  UNIVERSIDAD NACIONAL DE COLOMBIA
# 4               1101                  UNIVERSIDAD NACIONAL DE COLOMBIA
#
#    codigodepartinstitucion nombredepartinstitucion  \
# 0                        5               ANTIOQUIA
# 1                       11              BOGOTA D.C
# 2                       11              BOGOTA D.C
# 3                       11              BOGOTA D.C
# 4                       11              BOGOTA D.C
#
#    codigomunicipioinstitucion nombremunicipioinstitucion  \
# 0                        5001                   MEDELLIN
# 1                       11001                BOGOTA D.C.
# ...

# %%
df.replace(np.nan, '', regex=True)
df = df.fillna('').apply(lambda x: x.astype(str).str.upper())
df['nombreprograma'] = df['nombreprograma'].str.replace(u'¿C', 'EC')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'¿N', 'ON')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'R¿S', 'RIS')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'R¿C', 'RIC')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'R¿F', 'RAF')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'¿O', 'ÑO')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'F¿', 'FE')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'M¿T', 'MAT')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'G¿A', 'GIA')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'C¿N', 'CAN')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'R¿L', 'ROL')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'P¿B', 'PUB')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'Á', 'A')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'É', 'E')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'Í', 'I')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'Ó', 'O')
df['nombreprograma'] = df['nombreprograma'].str.replace(u'Ú', 'U')
df['nombreprograma']
# Out:
# 0        TECNOLOGIA EN HOTELERIA TURISMO Y RELACIONES P...
# 1                               ESPECIALIDAD EN ENDODONCIA
# 2            MAESTRIA EN CIENCIA Y TECNOLOGIA DE ALIMENTOS
# 3        ESPECIALIZACION EN MERCADOS Y POLITICAS DE SUE...
# 4                               MAESTRIA EN TRABAJO SOCIAL
# 5               ESPECIALIZACION EN SISTEMAS DE INFORMACION
# 6         ESPECIALIZACION EN ENFERMERIA CARDIORESPIRATORIA
# 7        ESPECIALIZACION EN AUTOMATIZACION DE EQUIPOS Y...
# 8                                   MAESTRIA EN INGENIERIA
# 9                                   INGENIERIA EN MERCADEO
# 10                                       INGENIERIA FISICA
# 11                                         ARTES PLASTICAS
# 12                               INGENIERIA ADMINISTRATIVA
# 13                                            ARQUITECTURA
# 14                      MAESTRIA EN CIENCIAS - ENTOMOLOGIA
# 15                              LICENCIATURA EN LITERATURA
# ...

# %%
df.to_csv('PROGRAMAS_EDUCACION_UPPERCASE.csv', sep=',', index=False)
